# %% [markdown]
# # Model for Autogen Agents

# %% [markdown]
# # Gemini

# %%
from autogen_core.models import UserMessage, ModelInfo
from autogen_ext.models.openai import OpenAIChatCompletionClient


gemini_info = ModelInfo(
    vision=True,
    function_calling=True,
    json_output=True,
    family="gemini" 
)

model_client = OpenAIChatCompletionClient(
    model="gemini-2.5-flash",
    api_key="AIzaSyDyapFApbMGspefX1TDXhM_7sksEl_Vi1U",
    model_info=gemini_info
)

response = await model_client.create([UserMessage(content="What is the capital of France?", source="user")])
print(response)

await model_client.close()
# Out:
# finish_reason='stop' content='The capital of France is **Paris**.' usage=RequestUsage(prompt_tokens=8, completion_tokens=8) cached=False logprobs=None thought=None

# %% [markdown]
# # Open Router

# %%
open_router_api_key = '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'

open_router_model_client =  OpenAIChatCompletionClient(
    base_url="https://openrouter.ai/api/v1",
    model="deepseek/deepseek-r1-0528:free",
    api_key = open_router_api_key,
    model_info={
        "family":'deepseek',
        "vision" :True,
        "function_calling":True,
        "json_output": False
    }
)


response = await open_router_model_client.create([UserMessage(content="What is the capital of France?", source="user")])

print(response)
await model_client.close()
# Out:
# finish_reason='stop' content='The capital of France is **Paris**.  \n\nParis is renowned for its art, fashion, cuisine, and historic landmarks like the **Eiffel Tower**, **Notre-Dame Cathedral**, and the **Louvre Museum**. It has been the political and cultural center of France for centuries.' usage=RequestUsage(prompt_tokens=13, completion_tokens=225) cached=False logprobs=None thought=None

# %% [markdown]
# # Ollama

# %%
from autogen_core.models import UserMessage
from autogen_ext.models.ollama import OllamaChatCompletionClient

# Assuming your Ollama server is running locally on port 11434.
ollama_model_client = OllamaChatCompletionClient(model="qwen2.5vl:3b")

response = await ollama_model_client.create([UserMessage(content="What is the capital of France?", source="user")])
print(response)
await ollama_model_client.close()
# Out:
# finish_reason='stop' content='The capital of France is Paris.' usage=RequestUsage(prompt_tokens=27, completion_tokens=8) cached=False logprobs=None thought=None
